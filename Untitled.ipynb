# %%
import pandas as pd

# %%
phones_df = pd.read_csv('data_phone_have_price.csv')
phones_df
# Out:
#      brand     technology            touch_screen display_colors screen_size  \
# 0       A1        IPS LCD  capacitive touchscreen            16M   6.26" inc
# 1       A1        IPS LCD  capacitive touchscreen            16M    5.5" inc
# 2     Acer        IPS LCD  capacitive touchscreen            16M      5" inc
# 3     Acer        IPS LCD  capacitive touchscreen            16M    5.5" inc
# 4     Acer        IPS LCD  capacitive touchscreen            16M      5" inc
# ...    ...            ...                     ...            ...         ...
# 4279   Zte            TFT  capacitive touchscreen            16M    4.3" inc
# 4280   Zte            TFT  capacitive touchscreen            16M    4.3" inc
# 4281   Zte            TFT   resistive touchscreen            65K      0" inc
# 4282   Zte  AMOLED or LCD  capacitive touchscreen           256K    3.5" inc
# 4283   Zte            TFT   resistive touchscreen           256K    2.8" inc
#
# ...

# %%
phones_df.isnull().sum()
# Out:
# brand                      0
# technology               158
# touch_screen             185
# display_colors           233
# screen_size                0
# screen_area                0
# screen_to_body_ratio       0
# screen_resolution          0
# rear_camera                0
# front_camera               0
# os                         2
# gpu                        0
# external_memory            4
# internal_memory           76
# cpu                      112
# dimensions                 0
# weight                     0
# battery                    0
# approximate_price          0
# sim_card                   0
# net_work                   0
# speed                    206
# gprs                       3
# gps                        3
# wifi                       1
# nfc                     3019
# usb                        2
# bluetooth                  2
# radio                    135
# headphone_jack             6
# dtype: int64

# %%
phones_df.display_colors.unique()
# Out:
# array(['16M', nan, '256K', '65K', '1B', 'Type IPS L', 'Type OLED',
#        'Type LTPS', '16М', 'Type P-OLE', 'Type AMOLE', 'Type Super'],
#       dtype=object)

# %%
phones_df.os.unique()
# Out:
# array(['Android 9.0 (Pie)', 'Android 8.1 (Oreo)',
#        'Android 6.0 (Marshmallow)', 'Microsoft Windows 10',
#        'Android 5.0 (Lollipop)', 'Microsoft Windows Phone 8.1',
#        'Android 5.1 (Lollipop)', 'Android 4.4.4 (KitKat)',
#        'Android 4.4.2 (KitKat)', 'Android 4.2.2 (Jelly Bean)',
#        'Android 4.4.4 (KitKat), upgradable to 5.1 (Lollipop)',
#        'Android 4.2 (Jelly Bean)', 'Android 4.0 (Ice Cream Sandwich)',
#        'Android 4.1.1 (Jelly Bean)', 'Android 4.2.1 (Jelly Bean)',
#        'Android 4.2 (Jelly Bean); Float UI',
#        'Android 4.0.3 (Ice Cream Sandwich)', 'Android 2.3 (Gingerbread)',
#        'Microsoft Windows Phone 7.5 Mango', 'Android 2.2 (Froyo)',
#        'Android 2.2 (Froyo), upgradable to 2.3 (Gingerbread)',
#        'Android 1.5 (Cupcake)', 'Android 1.6 (Donut)',
#        'Android 2.1 (Eclair)', 'Android-based OPhone 1.5',
#        'Android 2.1 (Eclair), upgradable to Android 2.2 (Froyo)',
#        'Microsoft Windows Mobile 6.5.3',
# ...

# %%
phones_df[phones_df.display_colors == '16М']
# Out:
#       brand technology            touch_screen display_colors screen_size  \
# 2367  Nokia    IPS LCD  capacitive touchscreen            16М   6.39" inc
# 2372  Nokia    IPS LCD  capacitive touchscreen            16М   5.45" inc
# 3715   Vivo    IPS LCD  capacitive touchscreen            16М   6.58" inc
# 3738   Vivo    IPS LCD  capacitive touchscreen            16М   6.51" inc
#
#      screen_area screen_to_body_ratio screen_resolution   rear_camera  \
# 2367   100.2 cm2                81.9%     720 x 1560 px   48 MP, Quad
# 2372    76.7 cm2                72.2%      480 x 960 px  5 MP, Single
# 3715   104.5 cm2                84.4%    1080 x 2400 px   48 MP, Dual
# 3738   102.3 cm2                81.6%     720 x 1600 px   13 MP, Dual
#
#        front_camera  ...                      net_work  \
# 2367  16 MP, Single  ...              GSM / HSPA / LTE
# 2372   5 MP, Single  ...              GSM / HSPA / LTE
# 3715  20 MP, Single  ...  GSM / CDMA / HSPA / LTE / 5G
# ...

# %%
phones_df.display_colors.iloc[2367][-1] == 'М'
# Out:
# True

# %%
'М' != 'M'
# Out:
# True

# %%
'М' != 'M'
# Out:
# True

# %%
'M' != 'M'
# Out:
# False

# %%
phones_df[phones_df.duplicated()]
# Out:
#          brand         technology            touch_screen display_colors  \
# 319       Asus            IPS LCD  capacitive touchscreen            16M
# 321       Asus            IPS LCD  capacitive touchscreen            16M
# 341       Asus            IPS LCD  capacitive touchscreen            16M
# 391       Asus            IPS LCD  capacitive touchscreen            16M
# 720   Gigabyte            IPS LCD  capacitive touchscreen            16M
# 721   Gigabyte            IPS LCD  capacitive touchscreen            16M
# 988        Htc         Super LCD2  capacitive touchscreen            16M
# 992        Htc       Super AMOLED  capacitive touchscreen            16M
# 1015       Htc              S-LCD  capacitive touchscreen            16M
# 1203    Huawei            IPS LCD  capacitive touchscreen            16M
# 1218    Huawei            IPS LCD  capacitive touchscreen            16M
# 1237    Huawei          S-IPS LCD  capacitive touchscreen            16M
# ...

# %%
phones_df = phones_df.drop_duplicates()
phones_df
# Out:
#      brand     technology            touch_screen display_colors screen_size  \
# 0       A1        IPS LCD  capacitive touchscreen            16M   6.26" inc
# 1       A1        IPS LCD  capacitive touchscreen            16M    5.5" inc
# 2     Acer        IPS LCD  capacitive touchscreen            16M      5" inc
# 3     Acer        IPS LCD  capacitive touchscreen            16M    5.5" inc
# 4     Acer        IPS LCD  capacitive touchscreen            16M      5" inc
# ...    ...            ...                     ...            ...         ...
# 4279   Zte            TFT  capacitive touchscreen            16M    4.3" inc
# 4280   Zte            TFT  capacitive touchscreen            16M    4.3" inc
# 4281   Zte            TFT   resistive touchscreen            65K      0" inc
# 4282   Zte  AMOLED or LCD  capacitive touchscreen           256K    3.5" inc
# 4283   Zte            TFT   resistive touchscreen           256K    2.8" inc
#
# ...

# %%
phones_df.battery
# Out:
# 0       3200 mAh,  Non-removable Li-Ion
# 1       2900 mAh,  Non-removable Li-Ion
# 2           2000 mAh,  Removable Li-Ion
# 3        4080 mAh,  Non-removable Li-Po
# 4           2000 mAh,  Removable Li-Ion
#                      ...
# 4279        1400 mAh,  Removable Li-Ion
# 4280        1400 mAh,  Removable Li-Ion
# 4281                             0 mAh,
# 4282        1250 mAh,  Removable Li-Ion
# 4283        1100 mAh,  Removable Li-Ion
# Name: battery, Length: 4242, dtype: object

# %%
phones_df.screen_size.str.replace('" inc', "")
# Out:
# 0       6.26
# 1        5.5
# 2          5
# 3        5.5
# 4          5
#         ...
# 4279     4.3
# 4280     4.3
# 4281       0
# 4282     3.5
# 4283     2.8
# Name: screen_size, Length: 4242, dtype: object

# %%
phones_df.screen_area.str.replace('cm2', "")[4281]
# Out:
# ''

# %%
def cvtFloat(x):
    if type(x) == str:
        temp = x.split()[0]
    else:
        temp = x
    val = None
    try:
        val = float(temp)
    except ValueError:
        return val
    return val

# %%
df['screen_area'].apply(cvtFloat)
# Out:
# 0       97.8
# 1       78.1
# 2       68.9
# 3       83.4
# 4       68.9
#         ...
# 4279    52.6
# 4280    52.6
# 4281     NaN
# 4282    34.9
# 4283    24.3
# Name: screen_area, Length: 4284, dtype: float64

# %%
df['screen_size'].apply(cvtFloat)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 4279    None
# 4280    None
# 4281    None
# 4282    None
# 4283    None
# Name: screen_size, Length: 4284, dtype: object

# %%
a = phones_df.screen_resolution.str.replace(' px','').str.split(' x ')

# %%
float(phones_df.screen_resolution.str.replace(' px','').str.replace(' x ', '*')[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-899c3448337b> in <module>
# ----> 1 float(phones_df.screen_resolution.str.replace(' px','').str.replace(' x ', '*')[0])
#
# ValueError: could not convert string to float: '720*1520'

# %%
float(a[0][0])*float(a[0][1])
# Out:
# 1094400.0

# %%
df = pd.read_csv('data_phone_have_price.csv')
df.approximate_price[2145:2155]
# Out:
# 2145      $ 110
# 2146    150 EUR
# 2147    300 EUR
# 2148    400 EUR
# 2149    180 EUR
# 2150    290 EUR
# 2151    270 EUR
# 2152    220 EUR
# 2153    230 EUR
# 2154    € 169.9
# Name: approximate_price, dtype: object

# %%
df.isnull().sum()
# Out:
# brand                      0
# technology               158
# touch_screen             185
# display_colors           233
# screen_size                0
# screen_area                0
# screen_to_body_ratio       0
# screen_resolution          0
# rear_camera                0
# front_camera               0
# os                         2
# gpu                        0
# external_memory            4
# internal_memory           76
# cpu                      112
# dimensions                 0
# weight                     0
# battery                    0
# approximate_price          0
# sim_card                   0
# net_work                   0
# speed                    206
# gprs                       3
# gps                        3
# wifi                       1
# nfc                     3019
# usb                        2
# bluetooth                  2
# radio                    135
# headphone_jack             6
# dtype: int64

# %%
df1 = pd.read_csv('data_phone.csv')
df1.nfc
# Out:
# 0       Yes (64/3GB model only)
# 1                           Yes
# 2                           NaN
# 3                           NaN
# 4                           NaN
#                  ...
# 5672                        NaN
# 5673                        NaN
# 5674                        NaN
# 5675                        NaN
# 5676                        NaN
# Name: nfc, Length: 5677, dtype: object

# %%
from sklearn.impute import SimpleImputer

# %%
import numpy as np

# %%
imp_mean = SimpleImputer(missing_values=None, strategy='most_frequent')
imp_mean.fit(df1.approximate_price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-36254dfcc4c3> in <module>
#       1 imp_mean = SimpleImputer(missing_values=None, strategy='most_frequent')
# ----> 2 imp_mean.fit(df1.approximate_price)
#
# E:\Anaconda\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     275         self : SimpleImputer
#     276         """
# --> 277         X = self._validate_input(X, in_fit=True)
#     278         super()._fit_indicator(X)
#     279
#
# E:\Anaconda\lib\site-packages\sklearn\impute\_base.py in _validate_input(self, X, in_fit)
#     249                 raise new_ve from None
#     250             else:
# --> 251                 raise ve
#     252
#     253         _check_inputs_dtype(X, self.missing_values)
#
# E:\Anaconda\lib\site-packages\sklearn\impute\_base.py in _validate_input(self, X, in_fit)
#     239
#     240         try:
# ...

# %%
imp_mean = SimpleImputer(missing_values=None, strategy='mean')
imp_mean.fit([[7, 2, 3], [4, 'None', 6], [10, 5, 9]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-7eeceb4a223b> in <module>
#       1 imp_mean = SimpleImputer(missing_values=None, strategy='mean')
# ----> 2 imp_mean.fit([[7, 2, 3], [4, 'None', 6], [10, 5, 9]])
#
# E:\Anaconda\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     275         self : SimpleImputer
#     276         """
# --> 277         X = self._validate_input(X, in_fit=True)
#     278         super()._fit_indicator(X)
#     279
#
# E:\Anaconda\lib\site-packages\sklearn\impute\_base.py in _validate_input(self, X, in_fit)
#     247                 new_ve = ValueError("Cannot use {} strategy with non-numeric "
#     248                                     "data:\n{}".format(self.strategy, ve))
# --> 249                 raise new_ve from None
#     250             else:
#     251                 raise ve
#
# ...

# %%
X = [[np.nan, 2, 3], [4, np.nan, 6], [10, np.nan, 9]]
print(imp_mean.transform(X))
# Out:
# [[ 7.   2.   3. ]
#  [ 4.   3.5  6. ]
#  [10.   3.5  9. ]]

# %%
df1.approximate_price[5676] = np.nan

# %%
df1.approximate_price
# Out:
# 0       150 EUR
# 1       120 EUR
# 2          None
# 3       120 EUR
# 4       250 EUR
#          ...
# 5672       None
# 5673    180 EUR
# 5674       None
# 5675       None
# 5676        NaN
# Name: approximate_price, Length: 5677, dtype: object
